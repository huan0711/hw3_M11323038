# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
import pandas as pd
import random
# Out:
# 2025-05-22 06:03:04.450238: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-22 06:03:04.487341: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
# Define paths
BASE_PATH = "../data"
FOLDS = ["Fold1", "Fold2", "Fold3", "Fold4", "Fold5"]
IMG_SIZE = (256, 256)
PIXELS_PER_CM = 72
BATCH_SIZE = 4
EPOCHS = 50
LEARNING_RATE = 1e-4

OUTPUT_DIR = "Unet_result"
FIGURE_DIR = os.path.join(OUTPUT_DIR, "figure")
MODELS_DIR = os.path.join(OUTPUT_DIR, "models")
RESULTS_DIR = os.path.join(OUTPUT_DIR, "results")

# Create output directories
for dir_path in [OUTPUT_DIR, FIGURE_DIR, MODELS_DIR, RESULTS_DIR]:
    os.makedirs(dir_path, exist_ok=True)

# %%
def load_image(image_path):
    """載入並前處理圖像"""
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"無法讀取圖像: {image_path}")
        return np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)

    img = cv2.resize(img, IMG_SIZE)
    img = img.astype(np.float32) / 255.0
    img = np.expand_dims(img, axis=-1)  # (H, W, 1)
    return img

# %%
def load_mask(mask_path):
    """載入並前處理遮罩，確保嚴格的二值化"""
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        print(f"無法讀取遮罩: {mask_path}")
        return np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)

    mask = cv2.resize(mask, IMG_SIZE)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)
    return mask

# %%
def augment_data(image, mask):
    """對圖像和遮罩進行數據增強"""
    # 確保輸入形狀正確
    if image.ndim != 3 or image.shape[2] != 1:
        image = cv2.resize(image, IMG_SIZE)
        if image.ndim == 2:
            image = np.expand_dims(image, axis=-1)
        elif image.shape[2] > 1:
            image = np.expand_dims(image[:, :, 0], axis=-1)

    if mask.ndim != 3 or mask.shape[2] != 1:
        mask = cv2.resize(mask, IMG_SIZE)
        if mask.ndim == 2:
            mask = np.expand_dims(mask, axis=-1)
        elif mask.shape[2] > 1:
            mask = np.expand_dims(mask[:, :, 0], axis=-1)

    # 暫時將遮罩從 (256,256,1) 轉換為 (256,256) 進行處理
    mask_2d = np.squeeze(mask)

    # 水平翻轉
    if random.random() > 0.5:
        image = np.fliplr(image)
        mask_2d = np.fliplr(mask_2d)

    # 旋轉±10度
    if random.random() > 0.5:
        angle = random.uniform(-10, 10)
        h, w = image.shape[:2]
        center = (w // 2, h // 2)
        rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

        image = cv2.warpAffine(image, rotation_matrix, (w, h),
                               flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT)
        mask_2d = cv2.warpAffine(mask_2d, rotation_matrix, (w, h),
                                 flags=cv2.INTER_NEAREST, borderMode=cv2.BORDER_CONSTANT)

    # 確保返回的形狀為 (256,256,1)
    image = np.reshape(image, (IMG_SIZE[0], IMG_SIZE[1], 1))
    mask = np.reshape(mask_2d, (IMG_SIZE[0], IMG_SIZE[1], 1))

    image = image.astype(np.float32)
    mask = (mask > 0.5).astype(np.float32)

    return image, mask

# %%
def match_images_and_masks(image_paths, mask_paths):
    """匹配圖像和遮罩路徑，對大小寫不敏感"""
    image_basenames = {}
    for p in image_paths:
        basename = os.path.splitext(os.path.basename(p))[0].lower()
        image_basenames[basename] = p

    mask_basenames_map = {}
    for p in mask_paths:
        basename = os.path.splitext(os.path.basename(p))[0].lower()
        if basename.startswith('mask_'):
            mask_basenames_map[basename[5:]] = p
        else:
            mask_basenames_map[basename] = p

    matched_image_paths = []
    matched_mask_paths = []
    unmatched_images = []

    for img_key, img_path in image_basenames.items():
        if img_key in mask_basenames_map:
            matched_image_paths.append(img_path)
            matched_mask_paths.append(mask_basenames_map[img_key])
        else:
            unmatched_images.append(img_path)

    if unmatched_images:
        print(f"未匹配的圖像檔案: {unmatched_images[:5]} (總共 {len(unmatched_images)} 個)")

    print(f"匹配到 {len(matched_image_paths)} 對圖像和遮罩 (原始圖像數: {len(image_paths)}, 原始遮罩數: {len(mask_paths)})")
    return matched_image_paths, matched_mask_paths

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_paths, mask_paths, batch_size=BATCH_SIZE, augment=False, shuffle=True):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.batch_size = batch_size
        self.augment = augment
        self.shuffle = shuffle
        self.indexes = np.arange(len(image_paths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, index):
        batch_indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        current_batch_size = len(batch_indexes)

        batch_images = np.zeros((current_batch_size, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
        batch_masks = np.zeros((current_batch_size, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)

        for i, idx in enumerate(batch_indexes):
            try:
                image = load_image(self.image_paths[idx])
                mask = load_mask(self.mask_paths[idx])

                if self.augment:
                    image, mask = augment_data(image, mask)

                # 確保形狀正確
                image = np.reshape(image, (IMG_SIZE[0], IMG_SIZE[1], 1))
                mask = np.reshape(mask, (IMG_SIZE[0], IMG_SIZE[1], 1))

                batch_images[i] = image
                batch_masks[i] = mask
            except Exception as e:
                print(f"處理圖像 {self.image_paths[idx]} 或遮罩 {self.mask_paths[idx]} 時出錯: {e}")
                batch_images[i] = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
                batch_masks[i] = np.zeros((IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
        return batch_images, batch_masks

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
def find_ett_endpoint_with_x(mask_squeezed):
    """尋找氣管內管的端點 (y座標) 和對應的 x 座標中點"""
    binary_mask = (mask_squeezed > 0.5).astype(np.uint8)
    white_pixels_y, white_pixels_x = np.where(binary_mask > 0)

    if len(white_pixels_y) == 0:
        return 0, 0

    endpoint_y = np.max(white_pixels_y)
    x_at_endpoint_y = white_pixels_x[white_pixels_y == endpoint_y]
    if len(x_at_endpoint_y) == 0:
        endpoint_x = np.mean(white_pixels_x) if len(white_pixels_x) > 0 else 0
    else:
        endpoint_x = np.mean(x_at_endpoint_y)

    return int(round(endpoint_y)), int(round(endpoint_x))

# %%
def calculate_custom_metrics(gt_endpoints_y, pred_endpoints_y, pixels_per_cm=PIXELS_PER_CM):
    """計算自定義評估指標 (僅基於 y 座標)"""
    gt_endpoints_y = np.array(gt_endpoints_y)
    pred_endpoints_y = np.array(pred_endpoints_y)

    if len(gt_endpoints_y) == 0 or len(pred_endpoints_y) == 0:
        print("警告: 端點列表為空，無法計算自定義指標。")
        return {
            'mean_error_cm': np.nan,
            'acc_within_05cm': np.nan,
            'acc_within_10cm': np.nan
        }
    if len(gt_endpoints_y) != len(pred_endpoints_y):
        print(f"警告: gt_endpoints ({len(gt_endpoints_y)}) 和 pred_endpoints ({len(pred_endpoints_y)}) 長度不匹配。")
        min_len = min(len(gt_endpoints_y), len(pred_endpoints_y))
        gt_endpoints_y = gt_endpoints_y[:min_len]
        pred_endpoints_y = pred_endpoints_y[:min_len]
        if min_len == 0:
            return {
                'mean_error_cm': np.nan,
                'acc_within_05cm': np.nan,
                'acc_within_10cm': np.nan
            }

    abs_errors_px = np.abs(pred_endpoints_y - gt_endpoints_y)
    abs_errors_cm = abs_errors_px / pixels_per_cm

    mean_error_cm = np.mean(abs_errors_cm)
    accuracy_05cm = 100 * np.mean(abs_errors_px <= (pixels_per_cm / 2))
    accuracy_10cm = 100 * np.mean(abs_errors_px <= pixels_per_cm)

    return {
        'mean_error_cm': mean_error_cm,
        'acc_within_05cm': accuracy_05cm,
        'acc_within_10cm': accuracy_10cm
    }

# %%
def iou_metric(y_true, y_pred):
    if y_true.ndim > 2:
        y_true = np.squeeze(y_true)
    if y_pred.ndim > 2:
        y_pred = np.squeeze(y_pred)

    y_true_flat = y_true.flatten()
    y_pred_flat = (y_pred > 0.5).flatten().astype(np.uint8)
    if np.sum(y_true_flat) == 0 and np.sum(y_pred_flat) == 0:
        return 1.0
    return jaccard_score(y_true_flat, y_pred_flat, zero_division=1)

# %%
def post_process_prediction(pred):
    if pred.ndim == 2:
        pred = pred[..., np.newaxis]
    elif pred.ndim == 4:
        pred = pred[0]

    pred_binary = (pred > 0.5).astype(np.uint8)

    kernel = np.ones((3, 3), np.uint8)
    pred_binary = cv2.erode(pred_binary, kernel, iterations=1)
    pred_binary = cv2.dilate(pred_binary, kernel, iterations=1)

    if pred_binary.ndim == 2:
        pred_binary = pred_binary[..., np.newaxis]

    return pred_binary

# %%
def unet_model(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c1)
    c1 = layers.BatchNormalization()(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)
    skip_connections = [c1]

    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p1)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c2)
    c2 = layers.BatchNormalization()(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)
    skip_connections.append(c2)

    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p2)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c3)
    c3 = layers.BatchNormalization()(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)
    skip_connections.append(c3)

    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p3)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c4)
    c4 = layers.BatchNormalization()(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)
    skip_connections.append(c4)

    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p4)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c5)
    c5 = layers.BatchNormalization()(c5)

    u6 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, skip_connections.pop()])
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c6)
    c6 = layers.BatchNormalization()(c6)

    u7 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, skip_connections.pop()])
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c7)
    c7 = layers.BatchNormalization()(c7)

    u8 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, skip_connections.pop()])
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c8)
    c8 = layers.BatchNormalization()(c8)

    u9 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, skip_connections.pop()])
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c9)
    c9 = layers.BatchNormalization()(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid', kernel_initializer='he_normal')(c9)

    model = models.Model(inputs, outputs)
    return model

# %%
# def post_process_prediction(pred):
#     if pred.ndim == 2:
#         pred = pred[..., np.newaxis]
#     elif pred.ndim == 4:
#         pred = pred[0]

#     pred_binary = (pred > 0.5).astype(np.uint8)

#     kernel = np.ones((3, 3), np.uint8)
#     pred_binary = cv2.erode(pred_binary, kernel, iterations=1)
#     pred_binary = cv2.dilate(pred_binary, kernel, iterations=1)

#     if pred_binary.ndim == 2:
#         pred_binary = pred_binary[..., np.newaxis]

#     return pred_binary

# %%
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth))

# %%
def iou_score(y_true, y_pred):
    y_true = tf.cast(tf.greater(y_true, 0.5), tf.float32)
    y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection

    iou = (intersection + 1e-10) / (union + 1e-10)
    return tf.reduce_mean(iou)

# %%
def visualize_improved_results(image, true_mask, pred_mask, save_path=None, model_name="U-Net"):
    plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei', 'Microsoft YaHei', 'WenQuanYi Micro Hei']
    plt.rcParams['axes.unicode_minus'] = False

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    if image.ndim > 2:
        image = np.squeeze(image)
    if true_mask.ndim > 2:
        true_mask_squeezed = np.squeeze(true_mask)
    else:
        true_mask_squeezed = true_mask
    if pred_mask.ndim > 2:
        pred_mask_squeezed = np.squeeze(pred_mask)
    else:
        pred_mask_squeezed = pred_mask

    axes[0].set_title('Image')
    axes[0].imshow(image, cmap='gray')
    axes[0].axis('off')

    axes[1].set_title('Ground Truth Mask')
    background_color_gt = [75/255, 0/255, 130/255]
    bg_gt = np.ones((IMG_SIZE[0], IMG_SIZE[1], 3)) * background_color_gt
    axes[1].imshow(bg_gt)

    gt_display_mask = np.zeros((*true_mask_squeezed.shape, 4))
    gt_display_mask[true_mask_squeezed > 0.5, 1] = 0.8
    gt_display_mask[true_mask_squeezed > 0.5, 3] = 0.9
    axes[1].imshow(gt_display_mask)

    true_endpoint_y, true_endpoint_x = find_ett_endpoint_with_x(true_mask_squeezed)
    if true_endpoint_y > 0:
        axes[1].plot(true_endpoint_x, true_endpoint_y, 'ro', markersize=8, label='GT Endpoint')
        axes[1].text(true_endpoint_x + 5, true_endpoint_y, 'G', color='red', fontsize=12)
    axes[1].axis('off')

    axes[2].set_title('Predicted Mask')
    bg_pred = np.ones((IMG_SIZE[0], IMG_SIZE[1], 3)) * background_color_gt
    axes[2].imshow(bg_pred)

    binary_pred_squeezed = (pred_mask_squeezed > 0.5).astype(np.float32)

    if np.max(binary_pred_squeezed) > 0:
        pred_display_mask = np.zeros((*binary_pred_squeezed.shape, 4))
        pred_display_mask[binary_pred_squeezed > 0, 0] = 0.95
        pred_display_mask[binary_pred_squeezed > 0, 1] = 0.95
        pred_display_mask[binary_pred_squeezed > 0, 3] = 0.9
        axes[2].imshow(pred_display_mask)

        pred_endpoint_y, pred_endpoint_x = find_ett_endpoint_with_x(binary_pred_squeezed)
        if pred_endpoint_y > 0:
            axes[2].plot(pred_endpoint_x, pred_endpoint_y, 'ro', markersize=8, label='Pred Endpoint')
            axes[2].text(pred_endpoint_x + 5, pred_endpoint_y, 'Y', color='red', fontsize=12)
    else:
        axes[2].imshow(pred_mask_squeezed, cmap='viridis_r', alpha=0.7, vmin=0, vmax=1)
        cbar = plt.colorbar(axes[2].images[0], ax=axes[2], fraction=0.046, pad=0.04)
        cbar.set_label('Prediction Confidence')

    axes[2].axis('off')

    plt.suptitle(f"{model_name} Segmentation Results", fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.96])

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        plt.close(fig)
    else:
        plt.show()

# %%
def train_and_evaluate(fold, paths):
    print(f"=== 訓練 {fold} ===")

    train_img_paths = [os.path.join(paths['train'], f) for f in os.listdir(paths['train']) if f.endswith(('.jpg', '.jpeg'))]
    train_mask_paths = [os.path.join(paths['trainannot'], f) for f in os.listdir(paths['trainannot']) if f.endswith('.png')]

    val_img_paths = [os.path.join(paths['val'], f) for f in os.listdir(paths['val']) if f.endswith(('.jpg', '.jpeg'))]
    val_mask_paths = [os.path.join(paths['valannot'], f) for f in os.listdir(paths['valannot']) if f.endswith('.png')]

    test_img_paths = [os.path.join(paths['test'], f) for f in os.listdir(paths['test']) if f.endswith(('.jpg', '.jpeg'))]
    test_mask_paths = [os.path.join(paths['testannot'], f) for f in os.listdir(paths['testannot']) if f.endswith('.png')]

    print(f"訓練資料: 找到 {len(train_img_paths)} 張圖像, {len(train_mask_paths)} 張遮罩")
    print(f"驗證資料: 找到 {len(val_img_paths)} 張圖像, {len(val_mask_paths)} 張遮罩")
    print(f"測試資料: 找到 {len(test_img_paths)} 張圖像, {len(test_mask_paths)} 張遮罩")

    train_img_paths, train_mask_paths = match_images_and_masks(train_img_paths, train_mask_paths)
    val_img_paths, val_mask_paths = match_images_and_masks(val_img_paths, val_mask_paths)
    test_img_paths, test_mask_paths = match_images_and_masks(test_img_paths, test_mask_paths)

    if len(train_img_paths) == 0 or len(val_img_paths) == 0 or len(test_img_paths) == 0:
        print(f"警告: {fold} 中沒有足夠的匹配數據。跳過此 Fold。")
        return {
            'fold': fold, 'mean_iou': 0, 'mean_error_cm': np.nan,
            'acc_within_05cm': np.nan, 'acc_within_10cm': np.nan
        }, None

    train_generator = DataGenerator(train_img_paths, train_mask_paths, augment=True, shuffle=True)
    val_generator = DataGenerator(val_img_paths, val_mask_paths, augment=False, shuffle=False)

    model = unet_model()
    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss=dice_loss, metrics=['accuracy', iou_score])

    model_save_path = os.path.join(MODELS_DIR, f'best_model_fold{fold}.h5')
    checkpoint = ModelCheckpoint(model_save_path, monitor='val_iou_score', mode='max', save_best_only=True, verbose=1)
    early_stopping = EarlyStopping(monitor='val_iou_score', mode='max', patience=20, verbose=1)

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    if os.path.exists(model_save_path):
        print(f"載入最佳模型: {model_save_path}")
        model.load_weights(model_save_path)
    else:
        print(f"警告: 找不到最佳模型檔案 {model_save_path}。將使用訓練結束時的模型進行評估。")

    print(f"=== 評估 {fold} ===")
    gt_endpoints_y = []
    pred_endpoints_y = []
    test_ious = []

    if len(test_img_paths) == 0:
        print(f"警告: {fold} 沒有測試數據進行評估。")
        return {
            'fold': fold, 'mean_iou': 0, 'mean_error_cm': np.nan,
            'acc_within_05cm': np.nan, 'acc_within_10cm': np.nan
        }, history

    for i in range(len(test_img_paths)):
        image = load_image(test_img_paths[i])
        true_mask = load_mask(test_mask_paths[i])

        image_batch = np.expand_dims(image, axis=0)
        pred_mask_batch = model.predict(image_batch)
        pred_mask = pred_mask_batch[0]
        pred_mask = post_process_prediction(pred_mask)

        true_mask_squeezed = np.squeeze(true_mask)
        pred_mask_squeezed = np.squeeze(pred_mask)

        true_endpoint_y_val, _ = find_ett_endpoint_with_x(true_mask_squeezed)
        pred_endpoint_y_val, _ = find_ett_endpoint_with_x(pred_mask_squeezed)

        gt_endpoints_y.append(true_endpoint_y_val)
        pred_endpoints_y.append(pred_endpoint_y_val)

        iou = iou_metric(true_mask, pred_mask)
        test_ious.append(iou)

        img_basename = os.path.splitext(os.path.basename(test_img_paths[i]))[0]
        save_path = os.path.join(FIGURE_DIR, f'{fold}_test_img_{img_basename}.png')
        visualize_improved_results(image, true_mask, pred_mask, save_path, model_name="U-Net")

    custom_metrics = calculate_custom_metrics(gt_endpoints_y, pred_endpoints_y, pixels_per_cm=PIXELS_PER_CM)
    mean_iou = np.mean(test_ious) if test_ious else 0

    results = {
        'fold': fold,
        'mean_iou': mean_iou,
        'mean_error_cm': custom_metrics['mean_error_cm'],
        'acc_within_05cm': custom_metrics['acc_within_05cm'],
        'acc_within_10cm': custom_metrics['acc_within_10cm']
    }

    print(f"測試結果 - {fold}:")
    print(f"  平均 IoU: {mean_iou:.4f}")
    print(f"  平均誤差(公分): {custom_metrics.get('mean_error_cm', 'N/A'):.4f}")
    print(f"  誤差在0.5公分內準確率: {custom_metrics.get('acc_within_05cm', 'N/A'):.2f}%")
    print(f"  誤差在1.0公分內準確率: {custom_metrics.get('acc_within_10cm', 'N/A'):.2f}%")

    return results, history

# %%
def main():
    # Define paths for each fold
    PATHS = {
        'Fold1': {
            'train': os.path.join(BASE_PATH, 'Fold1', 'train'),
            'trainannot': os.path.join(BASE_PATH, 'Fold1', 'trainannot'),
            'val': os.path.join(BASE_PATH, 'Fold1', 'val'),
            'valannot': os.path.join(BASE_PATH, 'Fold1', 'valannot'),
            'test': os.path.join(BASE_PATH, 'Fold1', 'test'),
            'testannot': os.path.join(BASE_PATH, 'Fold1', 'testannot')
        },
        'Fold2': {
            'train': os.path.join(BASE_PATH, 'Fold2', 'train'),
            'trainannot': os.path.join(BASE_PATH, 'Fold2', 'trainannot'),
            'val': os.path.join(BASE_PATH, 'Fold2', 'val'),
            'valannot': os.path.join(BASE_PATH, 'Fold2', 'valannot'),
            'test': os.path.join(BASE_PATH, 'Fold2', 'test'),
            'testannot': os.path.join(BASE_PATH, 'Fold2', 'testannot')
        },
        'Fold3': {
            'train': os.path.join(BASE_PATH, 'Fold3', 'train'),
            'trainannot': os.path.join(BASE_PATH, 'Fold3', 'trainannot'),
            'val': os.path.join(BASE_PATH, 'Fold3', 'val'),
            'valannot': os.path.join(BASE_PATH, 'Fold3', 'valannot'),
            'test': os.path.join(BASE_PATH, 'Fold3', 'test'),
            'testannot': os.path.join(BASE_PATH, 'Fold3', 'testannot')
        },
        'Fold4': {
            'train': os.path.join(BASE_PATH, 'Fold4', 'train'),
            'trainannot': os.path.join(BASE_PATH, 'Fold4', 'trainannot'),
            'val': os.path.join(BASE_PATH, 'Fold4', 'val'),
            'valannot': os.path.join(BASE_PATH, 'Fold4', 'valannot'),
            'test': os.path.join(BASE_PATH, 'Fold4', 'test'),
            'testannot': os.path.join(BASE_PATH, 'Fold4', 'testannot')
        },
        'Fold5': {
            'train': os.path.join(BASE_PATH, 'Fold5', 'train'),
            'trainannot': os.path.join(BASE_PATH, 'Fold5', 'trainannot'),
            'val': os.path.join(BASE_PATH, 'Fold5', 'val'),
            'valannot': os.path.join(BASE_PATH, 'Fold5', 'valannot'),
            'test': os.path.join(BASE_PATH, 'Fold5', 'test'),
            'testannot': os.path.join(BASE_PATH, 'Fold5', 'testannot')
        }
    }

    all_results = []
    histories = {}

    for fold_name, paths in PATHS.items():
        print(f"\nProcessing {fold_name}...")
        try:
            results, history = train_and_evaluate(fold_name, paths)
            if results:
                all_results.append(results)
            if history:
                histories[fold_name] = history.history
        except Exception as e:
            print(f"處理 {fold_name} 時發生未預期錯誤: {e}")
            import traceback
            traceback.print_exc()
            continue

    if not all_results:
        print("錯誤: 沒有成功處理任何fold。請檢查數據路徑、文件格式和程式碼錯誤。")
        return

    valid_results = [r for r in all_results if r and not any(np.isnan(val) for val in [
        r.get('mean_iou', np.nan), r.get('mean_error_cm', np.nan),
        r.get('acc_within_05cm', np.nan), r.get('acc_within_10cm', np.nan)
    ])]

    if not valid_results:
        print("錯誤: 所有 Fold 的結果都無效，無法計算平均績效。")
        return

    mean_results = {
        'fold': 'Average',
        'mean_iou': np.mean([r['mean_iou'] for r in valid_results if 'mean_iou' in r]),
        'mean_error_cm': np.mean([r['mean_error_cm'] for r in valid_results if 'mean_error_cm' in r]),
        'acc_within_05cm': np.mean([r['acc_within_05cm'] for r in valid_results if 'acc_within_05cm' in r]),
        'acc_within_10cm': np.mean([r['acc_within_10cm'] for r in valid_results if 'acc_within_10cm' in r])
    }

    all_results.append(mean_results)

    results_df = pd.DataFrame(all_results)
    results_path = os.path.join(RESULTS_DIR, 'unet_results.csv')
    results_df.to_csv(results_path, index=False)

    print("\n=== 所有Fold平均績效 ===")
    print(f"平均 IoU: {mean_results['mean_iou']:.4f}")
    print(f"平均誤差(公分): {mean_results['mean_error_cm']:.4f}")
    print(f"誤差在0.5公分內準確率: {mean_results['acc_within_05cm']:.2f}%")
    print(f"誤差在1.0公分內準確率: {mean_results['acc_within_10cm']:.2f}%")

    print(f"\n所有結果已保存至: {results_path}")

    for fold_name, history_data in histories.items():
        if history_data:
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            plt.plot(history_data['loss'], label='Train Loss')
            if 'val_loss' in history_data:
                plt.plot(history_data['val_loss'], label='Val Loss')
            plt.title(f'{fold_name} - Loss')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.legend()

            plt.subplot(1, 2, 2)
            if 'iou_score' in history_data:
                plt.plot(history_data['iou_score'], label='Train IoU')
            if 'val_iou_score' in history_data:
                plt.plot(history_data['val_iou_score'], label='Val IoU')
            plt.title(f'{fold_name} - IoU Score')
            plt.xlabel('Epoch')
            plt.ylabel('IoU')
            plt.legend()

            plt.tight_layout()
            history_fig_path = os.path.join(FIGURE_DIR, f'{fold_name}_training_history.png')
            plt.savefig(history_fig_path)
            plt.close()
            print(f"{fold_name} 的訓練歷史曲線已保存至: {history_fig_path}")

if __name__ == "__main__":
    main()
# Out:
# Processing Fold1...
# === 訓練 Fold1 ===
# 訓練資料: 找到 287 張圖像, 287 張遮罩
# 驗證資料: 找到 47 張圖像, 47 張遮罩
# 測試資料: 找到 47 張圖像, 47 張遮罩
# 未匹配的圖像檔案: ['../data/Fold1/train/img_1.2.826.0.1.3680043.8.498.10001065121843652267743449160233082683.jpg', '../data/Fold1/train/img_1.2.826.0.1.3680043.8.498.10001175380298620851477409998730672515.jpg', '../data/Fold1/train/img_1.2.826.0.1.3680043.8.498.10001274045312501651093242392099983211.jpg', '../data/Fold1/train/img_1.2.826.0.1.3680043.8.498.10002446304107330308555550280339793610.jpg', '../data/Fold1/train/img_1.2.826.0.1.3680043.8.498.10003638361010097105432298560780077394.jpg'] (總共 144 個)
# 匹配到 143 對圖像和遮罩 (原始圖像數: 287, 原始遮罩數: 287)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# 2025-05-22 06:03:06.614482: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2052] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-05-22 06:03:06.637031: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2052] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-05-22 06:03:08.429181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78526 MB memory:  -> device: 0, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:1b:00.0, compute capability: 9.0
# Epoch 1/50
# 2025-05-22 06:03:14.605048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-05-22 06:03:16.484110: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f4c15aa6790 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-22 06:03:16.484143: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA H100 80GB HBM3, Compute Capability 9.0
# 2025-05-22 06:03:16.487649: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-22 06:03:16.568743: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 36/36 [==============================] - ETA: 0s - loss: 0.9760 - accuracy: 0.4838 - iou_score: 0.0135
# Epoch 1: val_iou_score improved from -inf to 0.00782, saving model to Unet_result/models/best_model_foldFold1.h5
# /root/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 19s 194ms/step - loss: 0.9760 - accuracy: 0.4838 - iou_score: 0.0135 - val_loss: 0.9837 - val_accuracy: 0.3410 - val_iou_score: 0.0078
# Epoch 2/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9641 - accuracy: 0.6763 - iou_score: 0.0254
# Epoch 2: val_iou_score improved from 0.00782 to 0.02380, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.9641 - accuracy: 0.6763 - iou_score: 0.0254 - val_loss: 0.9801 - val_accuracy: 0.8320 - val_iou_score: 0.0238
# Epoch 3/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9568 - accuracy: 0.7679 - iou_score: 0.0351
# Epoch 3: val_iou_score did not improve from 0.02380
# 36/36 [==============================] - 5s 140ms/step - loss: 0.9568 - accuracy: 0.7679 - iou_score: 0.0351 - val_loss: 0.9810 - val_accuracy: 0.6626 - val_iou_score: 0.0104
# Epoch 4/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9506 - accuracy: 0.8063 - iou_score: 0.0413
# Epoch 4: val_iou_score did not improve from 0.02380
# 36/36 [==============================] - 5s 140ms/step - loss: 0.9506 - accuracy: 0.8063 - iou_score: 0.0413 - val_loss: 0.9760 - val_accuracy: 0.9824 - val_iou_score: 0.0173
# Epoch 5/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9438 - accuracy: 0.8360 - iou_score: 0.0485
# Epoch 5: val_iou_score did not improve from 0.02380
# 36/36 [==============================] - 5s 140ms/step - loss: 0.9438 - accuracy: 0.8360 - iou_score: 0.0485 - val_loss: 0.9776 - val_accuracy: 0.9906 - val_iou_score: 0.0099
# Epoch 6/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9391 - accuracy: 0.8428 - iou_score: 0.0496
# Epoch 6: val_iou_score improved from 0.02380 to 0.03843, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.9391 - accuracy: 0.8428 - iou_score: 0.0496 - val_loss: 0.9318 - val_accuracy: 0.7812 - val_iou_score: 0.0384
# Epoch 7/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9321 - accuracy: 0.8683 - iou_score: 0.0579
# Epoch 7: val_iou_score improved from 0.03843 to 0.10592, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 171ms/step - loss: 0.9321 - accuracy: 0.8683 - iou_score: 0.0579 - val_loss: 0.8310 - val_accuracy: 0.9394 - val_iou_score: 0.1059
# Epoch 8/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9264 - accuracy: 0.8826 - iou_score: 0.0644
# Epoch 8: val_iou_score improved from 0.10592 to 0.10795, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.9264 - accuracy: 0.8826 - iou_score: 0.0644 - val_loss: 0.8214 - val_accuracy: 0.9438 - val_iou_score: 0.1079
# Epoch 9/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9215 - accuracy: 0.8915 - iou_score: 0.0696
# Epoch 9: val_iou_score improved from 0.10795 to 0.12778, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.9215 - accuracy: 0.8915 - iou_score: 0.0696 - val_loss: 0.7992 - val_accuracy: 0.9514 - val_iou_score: 0.1278
# Epoch 10/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9176 - accuracy: 0.8983 - iou_score: 0.0729
# Epoch 10: val_iou_score did not improve from 0.12778
# 36/36 [==============================] - 5s 138ms/step - loss: 0.9176 - accuracy: 0.8983 - iou_score: 0.0729 - val_loss: 0.8619 - val_accuracy: 0.9103 - val_iou_score: 0.0833
# Epoch 11/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9106 - accuracy: 0.9087 - iou_score: 0.0802
# Epoch 11: val_iou_score did not improve from 0.12778
# 36/36 [==============================] - 5s 137ms/step - loss: 0.9106 - accuracy: 0.9087 - iou_score: 0.0802 - val_loss: 0.8163 - val_accuracy: 0.9605 - val_iou_score: 0.1105
# Epoch 12/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9061 - accuracy: 0.9075 - iou_score: 0.0816
# Epoch 12: val_iou_score did not improve from 0.12778
# 36/36 [==============================] - 5s 137ms/step - loss: 0.9061 - accuracy: 0.9075 - iou_score: 0.0816 - val_loss: 0.8129 - val_accuracy: 0.9382 - val_iou_score: 0.1167
# Epoch 13/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8985 - accuracy: 0.9202 - iou_score: 0.0919
# Epoch 13: val_iou_score improved from 0.12778 to 0.14701, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 173ms/step - loss: 0.8985 - accuracy: 0.9202 - iou_score: 0.0919 - val_loss: 0.7667 - val_accuracy: 0.9562 - val_iou_score: 0.1470
# Epoch 14/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8915 - accuracy: 0.9261 - iou_score: 0.0982
# Epoch 14: val_iou_score did not improve from 0.14701
# 36/36 [==============================] - 5s 139ms/step - loss: 0.8915 - accuracy: 0.9261 - iou_score: 0.0982 - val_loss: 0.7862 - val_accuracy: 0.9477 - val_iou_score: 0.1301
# Epoch 15/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8860 - accuracy: 0.9296 - iou_score: 0.1028
# Epoch 15: val_iou_score improved from 0.14701 to 0.15803, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.8860 - accuracy: 0.9296 - iou_score: 0.1028 - val_loss: 0.7509 - val_accuracy: 0.9596 - val_iou_score: 0.1580
# Epoch 16/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8788 - accuracy: 0.9368 - iou_score: 0.1125
# Epoch 16: val_iou_score did not improve from 0.15803
# 36/36 [==============================] - 5s 140ms/step - loss: 0.8788 - accuracy: 0.9368 - iou_score: 0.1125 - val_loss: 0.7544 - val_accuracy: 0.9564 - val_iou_score: 0.1507
# Epoch 17/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8718 - accuracy: 0.9421 - iou_score: 0.1214
# Epoch 17: val_iou_score did not improve from 0.15803
# 36/36 [==============================] - 5s 142ms/step - loss: 0.8718 - accuracy: 0.9421 - iou_score: 0.1214 - val_loss: 0.7557 - val_accuracy: 0.9545 - val_iou_score: 0.1490
# Epoch 18/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8657 - accuracy: 0.9439 - iou_score: 0.1252
# Epoch 18: val_iou_score did not improve from 0.15803
# 36/36 [==============================] - 5s 141ms/step - loss: 0.8657 - accuracy: 0.9439 - iou_score: 0.1252 - val_loss: 0.7568 - val_accuracy: 0.9535 - val_iou_score: 0.1471
# Epoch 19/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.9464 - iou_score: 0.1309
# Epoch 19: val_iou_score did not improve from 0.15803
# 36/36 [==============================] - 5s 139ms/step - loss: 0.8603 - accuracy: 0.9464 - iou_score: 0.1309 - val_loss: 0.7816 - val_accuracy: 0.9451 - val_iou_score: 0.1297
# Epoch 20/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.9507 - iou_score: 0.1384
# Epoch 20: val_iou_score improved from 0.15803 to 0.15998, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 165ms/step - loss: 0.8512 - accuracy: 0.9507 - iou_score: 0.1384 - val_loss: 0.7361 - val_accuracy: 0.9581 - val_iou_score: 0.1600
# Epoch 21/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8426 - accuracy: 0.9543 - iou_score: 0.1469
# Epoch 21: val_iou_score improved from 0.15998 to 0.17583, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.8426 - accuracy: 0.9543 - iou_score: 0.1469 - val_loss: 0.7178 - val_accuracy: 0.9621 - val_iou_score: 0.1758
# Epoch 22/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8340 - accuracy: 0.9572 - iou_score: 0.1567
# Epoch 22: val_iou_score did not improve from 0.17583
# 36/36 [==============================] - 5s 139ms/step - loss: 0.8340 - accuracy: 0.9572 - iou_score: 0.1567 - val_loss: 0.7202 - val_accuracy: 0.9604 - val_iou_score: 0.1714
# Epoch 23/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8236 - accuracy: 0.9609 - iou_score: 0.1684
# Epoch 23: val_iou_score did not improve from 0.17583
# 36/36 [==============================] - 5s 138ms/step - loss: 0.8236 - accuracy: 0.9609 - iou_score: 0.1684 - val_loss: 0.7280 - val_accuracy: 0.9618 - val_iou_score: 0.1641
# Epoch 24/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8174 - accuracy: 0.9609 - iou_score: 0.1683
# Epoch 24: val_iou_score did not improve from 0.17583
# 36/36 [==============================] - 5s 140ms/step - loss: 0.8174 - accuracy: 0.9609 - iou_score: 0.1683 - val_loss: 0.7408 - val_accuracy: 0.9560 - val_iou_score: 0.1570
# Epoch 25/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8042 - accuracy: 0.9657 - iou_score: 0.1887
# Epoch 25: val_iou_score improved from 0.17583 to 0.21903, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 171ms/step - loss: 0.8042 - accuracy: 0.9657 - iou_score: 0.1887 - val_loss: 0.6537 - val_accuracy: 0.9714 - val_iou_score: 0.2190
# Epoch 26/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7950 - accuracy: 0.9676 - iou_score: 0.1964
# Epoch 26: val_iou_score did not improve from 0.21903
# 36/36 [==============================] - 5s 139ms/step - loss: 0.7950 - accuracy: 0.9676 - iou_score: 0.1964 - val_loss: 0.7072 - val_accuracy: 0.9626 - val_iou_score: 0.1739
# Epoch 27/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7819 - accuracy: 0.9706 - iou_score: 0.2109
# Epoch 27: val_iou_score improved from 0.21903 to 0.24513, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.7819 - accuracy: 0.9706 - iou_score: 0.2109 - val_loss: 0.6235 - val_accuracy: 0.9752 - val_iou_score: 0.2451
# Epoch 28/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7726 - accuracy: 0.9700 - iou_score: 0.2087
# Epoch 28: val_iou_score did not improve from 0.24513
# 36/36 [==============================] - 5s 139ms/step - loss: 0.7726 - accuracy: 0.9700 - iou_score: 0.2087 - val_loss: 0.6685 - val_accuracy: 0.9726 - val_iou_score: 0.2035
# Epoch 29/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7624 - accuracy: 0.9735 - iou_score: 0.2255
# Epoch 29: val_iou_score did not improve from 0.24513
# 36/36 [==============================] - 5s 139ms/step - loss: 0.7624 - accuracy: 0.9735 - iou_score: 0.2255 - val_loss: 0.6279 - val_accuracy: 0.9743 - val_iou_score: 0.2357
# Epoch 30/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7447 - accuracy: 0.9758 - iou_score: 0.2437
# Epoch 30: val_iou_score improved from 0.24513 to 0.24695, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.7447 - accuracy: 0.9758 - iou_score: 0.2437 - val_loss: 0.6173 - val_accuracy: 0.9782 - val_iou_score: 0.2469
# Epoch 31/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.9769 - iou_score: 0.2506
# Epoch 31: val_iou_score improved from 0.24695 to 0.30908, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.7341 - accuracy: 0.9769 - iou_score: 0.2506 - val_loss: 0.5416 - val_accuracy: 0.9838 - val_iou_score: 0.3091
# Epoch 32/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7158 - accuracy: 0.9791 - iou_score: 0.2701
# Epoch 32: val_iou_score did not improve from 0.30908
# 36/36 [==============================] - 5s 138ms/step - loss: 0.7158 - accuracy: 0.9791 - iou_score: 0.2701 - val_loss: 0.6342 - val_accuracy: 0.9724 - val_iou_score: 0.2288
# Epoch 33/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6982 - accuracy: 0.9815 - iou_score: 0.2965
# Epoch 33: val_iou_score improved from 0.30908 to 0.32025, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.6982 - accuracy: 0.9815 - iou_score: 0.2965 - val_loss: 0.5239 - val_accuracy: 0.9835 - val_iou_score: 0.3202
# Epoch 34/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.9830 - iou_score: 0.3133
# Epoch 34: val_iou_score did not improve from 0.32025
# 36/36 [==============================] - 5s 139ms/step - loss: 0.6816 - accuracy: 0.9830 - iou_score: 0.3133 - val_loss: 0.5312 - val_accuracy: 0.9831 - val_iou_score: 0.3114
# Epoch 35/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.9846 - iou_score: 0.3320
# Epoch 35: val_iou_score improved from 0.32025 to 0.34717, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 171ms/step - loss: 0.6629 - accuracy: 0.9846 - iou_score: 0.3320 - val_loss: 0.4983 - val_accuracy: 0.9871 - val_iou_score: 0.3472
# Epoch 36/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.9852 - iou_score: 0.3432
# Epoch 36: val_iou_score did not improve from 0.34717
# 36/36 [==============================] - 5s 139ms/step - loss: 0.6425 - accuracy: 0.9852 - iou_score: 0.3432 - val_loss: 0.5503 - val_accuracy: 0.9833 - val_iou_score: 0.2977
# Epoch 37/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6321 - accuracy: 0.9863 - iou_score: 0.3549
# Epoch 37: val_iou_score improved from 0.34717 to 0.35044, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.6321 - accuracy: 0.9863 - iou_score: 0.3549 - val_loss: 0.4908 - val_accuracy: 0.9864 - val_iou_score: 0.3504
# Epoch 38/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.9876 - iou_score: 0.3785
# Epoch 38: val_iou_score improved from 0.35044 to 0.39542, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 172ms/step - loss: 0.6103 - accuracy: 0.9876 - iou_score: 0.3785 - val_loss: 0.4418 - val_accuracy: 0.9895 - val_iou_score: 0.3954
# Epoch 39/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5934 - accuracy: 0.9883 - iou_score: 0.3889
# Epoch 39: val_iou_score improved from 0.39542 to 0.41096, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.5934 - accuracy: 0.9883 - iou_score: 0.3889 - val_loss: 0.4286 - val_accuracy: 0.9897 - val_iou_score: 0.4110
# Epoch 40/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5754 - accuracy: 0.9886 - iou_score: 0.3974
# Epoch 40: val_iou_score improved from 0.41096 to 0.44540, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.5754 - accuracy: 0.9886 - iou_score: 0.3974 - val_loss: 0.3950 - val_accuracy: 0.9913 - val_iou_score: 0.4454
# Epoch 41/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5579 - accuracy: 0.9901 - iou_score: 0.4306
# Epoch 41: val_iou_score did not improve from 0.44540
# 36/36 [==============================] - 5s 139ms/step - loss: 0.5579 - accuracy: 0.9901 - iou_score: 0.4306 - val_loss: 0.4500 - val_accuracy: 0.9890 - val_iou_score: 0.3891
# Epoch 42/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5344 - accuracy: 0.9907 - iou_score: 0.4431
# Epoch 42: val_iou_score improved from 0.44540 to 0.44657, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.5344 - accuracy: 0.9907 - iou_score: 0.4431 - val_loss: 0.3973 - val_accuracy: 0.9914 - val_iou_score: 0.4466
# Epoch 43/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5154 - accuracy: 0.9910 - iou_score: 0.4603
# Epoch 43: val_iou_score did not improve from 0.44657
# 36/36 [==============================] - 5s 142ms/step - loss: 0.5154 - accuracy: 0.9910 - iou_score: 0.4603 - val_loss: 0.4124 - val_accuracy: 0.9920 - val_iou_score: 0.4405
# Epoch 44/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4954 - accuracy: 0.9918 - iou_score: 0.4787
# Epoch 44: val_iou_score did not improve from 0.44657
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4954 - accuracy: 0.9918 - iou_score: 0.4787 - val_loss: 0.4332 - val_accuracy: 0.9883 - val_iou_score: 0.4194
# Epoch 45/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.9913 - iou_score: 0.4614
# Epoch 45: val_iou_score did not improve from 0.44657
# 36/36 [==============================] - 5s 137ms/step - loss: 0.4872 - accuracy: 0.9913 - iou_score: 0.4614 - val_loss: 0.3994 - val_accuracy: 0.9911 - val_iou_score: 0.4456
# Epoch 46/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4744 - accuracy: 0.9921 - iou_score: 0.4830
# Epoch 46: val_iou_score improved from 0.44657 to 0.48155, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 8s 213ms/step - loss: 0.4744 - accuracy: 0.9921 - iou_score: 0.4830 - val_loss: 0.3619 - val_accuracy: 0.9934 - val_iou_score: 0.4815
# Epoch 47/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4448 - accuracy: 0.9933 - iou_score: 0.5251
# Epoch 47: val_iou_score did not improve from 0.48155
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4448 - accuracy: 0.9933 - iou_score: 0.5251 - val_loss: 0.3861 - val_accuracy: 0.9910 - val_iou_score: 0.4551
# Epoch 48/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.9932 - iou_score: 0.5221
# Epoch 48: val_iou_score improved from 0.48155 to 0.49278, saving model to Unet_result/models/best_model_foldFold1.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4329 - accuracy: 0.9932 - iou_score: 0.5221 - val_loss: 0.3507 - val_accuracy: 0.9939 - val_iou_score: 0.4928
# Epoch 49/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.9939 - iou_score: 0.5402
# Epoch 49: val_iou_score did not improve from 0.49278
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4269 - accuracy: 0.9939 - iou_score: 0.5402 - val_loss: 0.3679 - val_accuracy: 0.9919 - val_iou_score: 0.4671
# Epoch 50/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.9942 - iou_score: 0.5592
# Epoch 50: val_iou_score did not improve from 0.49278
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3954 - accuracy: 0.9942 - iou_score: 0.5592 - val_loss: 0.3759 - val_accuracy: 0.9930 - val_iou_score: 0.4667
# 載入最佳模型: Unet_result/models/best_model_foldFold1.h5
# === 評估 Fold1 ===
# 1/1 [==============================] - 0s 412ms/step
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode MS, SimHei, Microsoft YaHei, WenQuanYi Micro Hei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode MS, SimHei, Microsoft YaHei, WenQuanYi Micro Hei
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 測試結果 - Fold1:
#   平均 IoU: 0.5284
#   平均誤差(公分): 0.1079
#   誤差在0.5公分內準確率: 100.00%
#   誤差在1.0公分內準確率: 100.00%
#
# Processing Fold2...
# === 訓練 Fold2 ===
# 訓練資料: 找到 287 張圖像, 287 張遮罩
# 驗證資料: 找到 47 張圖像, 47 張遮罩
# 測試資料: 找到 47 張圖像, 47 張遮罩
# 未匹配的圖像檔案: ['../data/Fold2/train/img_1.2.826.0.1.3680043.8.498.10001065121843652267743449160233082683.jpg', '../data/Fold2/train/img_1.2.826.0.1.3680043.8.498.10001175380298620851477409998730672515.jpg', '../data/Fold2/train/img_1.2.826.0.1.3680043.8.498.10001274045312501651093242392099983211.jpg', '../data/Fold2/train/img_1.2.826.0.1.3680043.8.498.10002446304107330308555550280339793610.jpg', '../data/Fold2/train/img_1.2.826.0.1.3680043.8.498.10003638361010097105432298560780077394.jpg'] (總共 144 個)
# 匹配到 143 對圖像和遮罩 (原始圖像數: 287, 原始遮罩數: 287)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# Epoch 1/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9759 - accuracy: 0.4957 - iou_score: 0.0136
# Epoch 1: val_iou_score improved from -inf to 0.00092, saving model to Unet_result/models/best_model_foldFold2.h5
# /root/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 13s 177ms/step - loss: 0.9759 - accuracy: 0.4957 - iou_score: 0.0136 - val_loss: 0.9869 - val_accuracy: 0.8456 - val_iou_score: 9.2379e-04
# Epoch 2/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9579 - accuracy: 0.7143 - iou_score: 0.0294
# Epoch 2: val_iou_score improved from 0.00092 to 0.00681, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.9579 - accuracy: 0.7143 - iou_score: 0.0294 - val_loss: 0.9858 - val_accuracy: 0.9713 - val_iou_score: 0.0068
# Epoch 3/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9446 - accuracy: 0.8244 - iou_score: 0.0468
# Epoch 3: val_iou_score did not improve from 0.00681
# 36/36 [==============================] - 5s 139ms/step - loss: 0.9446 - accuracy: 0.8244 - iou_score: 0.0468 - val_loss: 0.9891 - val_accuracy: 0.5731 - val_iou_score: 0.0041
# Epoch 4/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9375 - accuracy: 0.8532 - iou_score: 0.0548
# Epoch 4: val_iou_score improved from 0.00681 to 0.01187, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.9375 - accuracy: 0.8532 - iou_score: 0.0548 - val_loss: 0.9781 - val_accuracy: 0.3755 - val_iou_score: 0.0119
# Epoch 5/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9332 - accuracy: 0.8582 - iou_score: 0.0558
# Epoch 5: val_iou_score improved from 0.01187 to 0.04517, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.9332 - accuracy: 0.8582 - iou_score: 0.0558 - val_loss: 0.9376 - val_accuracy: 0.8334 - val_iou_score: 0.0452
# Epoch 6/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9281 - accuracy: 0.8723 - iou_score: 0.0614
# Epoch 6: val_iou_score did not improve from 0.04517
# 36/36 [==============================] - 5s 136ms/step - loss: 0.9281 - accuracy: 0.8723 - iou_score: 0.0614 - val_loss: 0.9519 - val_accuracy: 0.7464 - val_iou_score: 0.0276
# Epoch 7/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9224 - accuracy: 0.8844 - iou_score: 0.0662
# Epoch 7: val_iou_score improved from 0.04517 to 0.06299, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.9224 - accuracy: 0.8844 - iou_score: 0.0662 - val_loss: 0.8999 - val_accuracy: 0.9121 - val_iou_score: 0.0630
# Epoch 8/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9165 - accuracy: 0.8936 - iou_score: 0.0711
# Epoch 8: val_iou_score improved from 0.06299 to 0.08093, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 164ms/step - loss: 0.9165 - accuracy: 0.8936 - iou_score: 0.0711 - val_loss: 0.8784 - val_accuracy: 0.9376 - val_iou_score: 0.0809
# Epoch 9/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9108 - accuracy: 0.8985 - iou_score: 0.0738
# Epoch 9: val_iou_score did not improve from 0.08093
# 36/36 [==============================] - 5s 139ms/step - loss: 0.9108 - accuracy: 0.8985 - iou_score: 0.0738 - val_loss: 0.8720 - val_accuracy: 0.9233 - val_iou_score: 0.0797
# Epoch 10/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9029 - accuracy: 0.9089 - iou_score: 0.0815
# Epoch 10: val_iou_score improved from 0.08093 to 0.08203, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.9029 - accuracy: 0.9089 - iou_score: 0.0815 - val_loss: 0.8635 - val_accuracy: 0.9284 - val_iou_score: 0.0820
# Epoch 11/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8951 - accuracy: 0.9143 - iou_score: 0.0860
# Epoch 11: val_iou_score did not improve from 0.08203
# 36/36 [==============================] - 5s 139ms/step - loss: 0.8951 - accuracy: 0.9143 - iou_score: 0.0860 - val_loss: 0.8607 - val_accuracy: 0.9149 - val_iou_score: 0.0820
# Epoch 12/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8852 - accuracy: 0.9252 - iou_score: 0.0967
# Epoch 12: val_iou_score improved from 0.08203 to 0.10210, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 0.8852 - accuracy: 0.9252 - iou_score: 0.0967 - val_loss: 0.8248 - val_accuracy: 0.9351 - val_iou_score: 0.1021
# Epoch 13/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8760 - accuracy: 0.9315 - iou_score: 0.1047
# Epoch 13: val_iou_score improved from 0.10210 to 0.11908, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.8760 - accuracy: 0.9315 - iou_score: 0.1047 - val_loss: 0.7957 - val_accuracy: 0.9447 - val_iou_score: 0.1191
# Epoch 14/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8658 - accuracy: 0.9384 - iou_score: 0.1158
# Epoch 14: val_iou_score did not improve from 0.11908
# 36/36 [==============================] - 5s 138ms/step - loss: 0.8658 - accuracy: 0.9384 - iou_score: 0.1158 - val_loss: 0.8076 - val_accuracy: 0.9415 - val_iou_score: 0.1112
# Epoch 15/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8573 - accuracy: 0.9451 - iou_score: 0.1265
# Epoch 15: val_iou_score improved from 0.11908 to 0.11914, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 165ms/step - loss: 0.8573 - accuracy: 0.9451 - iou_score: 0.1265 - val_loss: 0.7927 - val_accuracy: 0.9443 - val_iou_score: 0.1191
# Epoch 16/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8490 - accuracy: 0.9492 - iou_score: 0.1353
# Epoch 16: val_iou_score did not improve from 0.11914
# 36/36 [==============================] - 5s 138ms/step - loss: 0.8490 - accuracy: 0.9492 - iou_score: 0.1353 - val_loss: 0.8411 - val_accuracy: 0.9188 - val_iou_score: 0.0902
# Epoch 17/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8445 - accuracy: 0.9493 - iou_score: 0.1373
# Epoch 17: val_iou_score did not improve from 0.11914
# 36/36 [==============================] - 5s 137ms/step - loss: 0.8445 - accuracy: 0.9493 - iou_score: 0.1373 - val_loss: 0.8645 - val_accuracy: 0.9058 - val_iou_score: 0.0760
# Epoch 18/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8334 - accuracy: 0.9527 - iou_score: 0.1456
# Epoch 18: val_iou_score did not improve from 0.11914
# 36/36 [==============================] - 5s 136ms/step - loss: 0.8334 - accuracy: 0.9527 - iou_score: 0.1456 - val_loss: 0.9302 - val_accuracy: 0.8050 - val_iou_score: 0.0373
# Epoch 19/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8239 - accuracy: 0.9586 - iou_score: 0.1614
# Epoch 19: val_iou_score improved from 0.11914 to 0.17213, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.8239 - accuracy: 0.9586 - iou_score: 0.1614 - val_loss: 0.7143 - val_accuracy: 0.9642 - val_iou_score: 0.1721
# Epoch 20/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8118 - accuracy: 0.9617 - iou_score: 0.1729
# Epoch 20: val_iou_score improved from 0.17213 to 0.17592, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.8118 - accuracy: 0.9617 - iou_score: 0.1729 - val_loss: 0.7081 - val_accuracy: 0.9646 - val_iou_score: 0.1759
# Epoch 21/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8014 - accuracy: 0.9640 - iou_score: 0.1806
# Epoch 21: val_iou_score did not improve from 0.17592
# 36/36 [==============================] - 5s 136ms/step - loss: 0.8014 - accuracy: 0.9640 - iou_score: 0.1806 - val_loss: 0.7118 - val_accuracy: 0.9644 - val_iou_score: 0.1725
# Epoch 22/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7880 - accuracy: 0.9687 - iou_score: 0.2038
# Epoch 22: val_iou_score improved from 0.17592 to 0.20736, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 0.7880 - accuracy: 0.9687 - iou_score: 0.2038 - val_loss: 0.6641 - val_accuracy: 0.9714 - val_iou_score: 0.2074
# Epoch 23/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.9694 - iou_score: 0.2064
# Epoch 23: val_iou_score did not improve from 0.20736
# 36/36 [==============================] - 5s 137ms/step - loss: 0.7788 - accuracy: 0.9694 - iou_score: 0.2064 - val_loss: 0.7177 - val_accuracy: 0.9630 - val_iou_score: 0.1769
# Epoch 24/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7645 - accuracy: 0.9721 - iou_score: 0.2243
# Epoch 24: val_iou_score did not improve from 0.20736
# 36/36 [==============================] - 5s 136ms/step - loss: 0.7645 - accuracy: 0.9721 - iou_score: 0.2243 - val_loss: 0.6887 - val_accuracy: 0.9683 - val_iou_score: 0.1896
# Epoch 25/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.9750 - iou_score: 0.2394
# Epoch 25: val_iou_score improved from 0.20736 to 0.25283, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.7521 - accuracy: 0.9750 - iou_score: 0.2394 - val_loss: 0.6053 - val_accuracy: 0.9793 - val_iou_score: 0.2528
# Epoch 26/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7387 - accuracy: 0.9763 - iou_score: 0.2490
# Epoch 26: val_iou_score improved from 0.25283 to 0.28305, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 163ms/step - loss: 0.7387 - accuracy: 0.9763 - iou_score: 0.2490 - val_loss: 0.5702 - val_accuracy: 0.9820 - val_iou_score: 0.2830
# Epoch 27/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.9781 - iou_score: 0.2662
# Epoch 27: val_iou_score did not improve from 0.28305
# 36/36 [==============================] - 5s 134ms/step - loss: 0.7227 - accuracy: 0.9781 - iou_score: 0.2662 - val_loss: 0.6552 - val_accuracy: 0.9717 - val_iou_score: 0.2200
# Epoch 28/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7085 - accuracy: 0.9788 - iou_score: 0.2747
# Epoch 28: val_iou_score did not improve from 0.28305
# 36/36 [==============================] - 5s 138ms/step - loss: 0.7085 - accuracy: 0.9788 - iou_score: 0.2747 - val_loss: 0.6655 - val_accuracy: 0.9730 - val_iou_score: 0.2080
# Epoch 29/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.9816 - iou_score: 0.2993
# Epoch 29: val_iou_score did not improve from 0.28305
# 36/36 [==============================] - 5s 139ms/step - loss: 0.6926 - accuracy: 0.9816 - iou_score: 0.2993 - val_loss: 0.6413 - val_accuracy: 0.9758 - val_iou_score: 0.2258
# Epoch 30/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.9837 - iou_score: 0.3291
# Epoch 30: val_iou_score improved from 0.28305 to 0.29335, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.6701 - accuracy: 0.9837 - iou_score: 0.3291 - val_loss: 0.5590 - val_accuracy: 0.9829 - val_iou_score: 0.2934
# Epoch 31/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.9848 - iou_score: 0.3381
# Epoch 31: val_iou_score did not improve from 0.29335
# 36/36 [==============================] - 5s 139ms/step - loss: 0.6526 - accuracy: 0.9848 - iou_score: 0.3381 - val_loss: 0.5688 - val_accuracy: 0.9815 - val_iou_score: 0.2851
# Epoch 32/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.9852 - iou_score: 0.3437
# Epoch 32: val_iou_score improved from 0.29335 to 0.34224, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.6379 - accuracy: 0.9852 - iou_score: 0.3437 - val_loss: 0.5078 - val_accuracy: 0.9866 - val_iou_score: 0.3422
# Epoch 33/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6217 - accuracy: 0.9867 - iou_score: 0.3669
# Epoch 33: val_iou_score did not improve from 0.34224
# 36/36 [==============================] - 5s 139ms/step - loss: 0.6217 - accuracy: 0.9867 - iou_score: 0.3669 - val_loss: 0.5043 - val_accuracy: 0.9867 - val_iou_score: 0.3414
# Epoch 34/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5988 - accuracy: 0.9877 - iou_score: 0.3895
# Epoch 34: val_iou_score did not improve from 0.34224
# 36/36 [==============================] - 5s 138ms/step - loss: 0.5988 - accuracy: 0.9877 - iou_score: 0.3895 - val_loss: 0.5257 - val_accuracy: 0.9856 - val_iou_score: 0.3260
# Epoch 35/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5784 - accuracy: 0.9893 - iou_score: 0.4157
# Epoch 35: val_iou_score improved from 0.34224 to 0.37146, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.5784 - accuracy: 0.9893 - iou_score: 0.4157 - val_loss: 0.4691 - val_accuracy: 0.9878 - val_iou_score: 0.3715
# Epoch 36/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5620 - accuracy: 0.9894 - iou_score: 0.4205
# Epoch 36: val_iou_score did not improve from 0.37146
# 36/36 [==============================] - 5s 140ms/step - loss: 0.5620 - accuracy: 0.9894 - iou_score: 0.4205 - val_loss: 0.5531 - val_accuracy: 0.9824 - val_iou_score: 0.2986
# Epoch 37/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.9896 - iou_score: 0.4236
# Epoch 37: val_iou_score improved from 0.37146 to 0.42686, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 165ms/step - loss: 0.5492 - accuracy: 0.9896 - iou_score: 0.4236 - val_loss: 0.4183 - val_accuracy: 0.9912 - val_iou_score: 0.4269
# Epoch 38/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.9914 - iou_score: 0.4678
# Epoch 38: val_iou_score improved from 0.42686 to 0.44091, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.5259 - accuracy: 0.9914 - iou_score: 0.4678 - val_loss: 0.3979 - val_accuracy: 0.9919 - val_iou_score: 0.4409
# Epoch 39/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.9912 - iou_score: 0.4613
# Epoch 39: val_iou_score did not improve from 0.44091
# 36/36 [==============================] - 5s 138ms/step - loss: 0.5071 - accuracy: 0.9912 - iou_score: 0.4613 - val_loss: 0.4075 - val_accuracy: 0.9905 - val_iou_score: 0.4321
# Epoch 40/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4836 - accuracy: 0.9924 - iou_score: 0.4953
# Epoch 40: val_iou_score improved from 0.44091 to 0.44200, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4836 - accuracy: 0.9924 - iou_score: 0.4953 - val_loss: 0.3942 - val_accuracy: 0.9931 - val_iou_score: 0.4420
# Epoch 41/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.9919 - iou_score: 0.4726
# Epoch 41: val_iou_score improved from 0.44200 to 0.46248, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.4860 - accuracy: 0.9919 - iou_score: 0.4726 - val_loss: 0.3857 - val_accuracy: 0.9920 - val_iou_score: 0.4625
# Epoch 42/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.9933 - iou_score: 0.5251
# Epoch 42: val_iou_score improved from 0.46248 to 0.53066, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4501 - accuracy: 0.9933 - iou_score: 0.5251 - val_loss: 0.3264 - val_accuracy: 0.9949 - val_iou_score: 0.5307
# Epoch 43/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.9939 - iou_score: 0.5498
# Epoch 43: val_iou_score did not improve from 0.53066
# 36/36 [==============================] - 5s 138ms/step - loss: 0.4318 - accuracy: 0.9939 - iou_score: 0.5498 - val_loss: 0.3701 - val_accuracy: 0.9926 - val_iou_score: 0.4782
# Epoch 44/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.9936 - iou_score: 0.5343
# Epoch 44: val_iou_score did not improve from 0.53066
# 36/36 [==============================] - 5s 136ms/step - loss: 0.4219 - accuracy: 0.9936 - iou_score: 0.5343 - val_loss: 0.3344 - val_accuracy: 0.9943 - val_iou_score: 0.5133
# Epoch 45/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4280 - accuracy: 0.9929 - iou_score: 0.5097
# Epoch 45: val_iou_score did not improve from 0.53066
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4280 - accuracy: 0.9929 - iou_score: 0.5097 - val_loss: 0.4012 - val_accuracy: 0.9908 - val_iou_score: 0.4423
# Epoch 46/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.9940 - iou_score: 0.5471
# Epoch 46: val_iou_score did not improve from 0.53066
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3981 - accuracy: 0.9940 - iou_score: 0.5471 - val_loss: 0.3561 - val_accuracy: 0.9937 - val_iou_score: 0.4928
# Epoch 47/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.9942 - iou_score: 0.5502
# Epoch 47: val_iou_score did not improve from 0.53066
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3912 - accuracy: 0.9942 - iou_score: 0.5502 - val_loss: 0.3716 - val_accuracy: 0.9926 - val_iou_score: 0.4758
# Epoch 48/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3598 - accuracy: 0.9949 - iou_score: 0.5913
# Epoch 48: val_iou_score improved from 0.53066 to 0.54761, saving model to Unet_result/models/best_model_foldFold2.h5
# 36/36 [==============================] - 6s 167ms/step - loss: 0.3598 - accuracy: 0.9949 - iou_score: 0.5913 - val_loss: 0.3164 - val_accuracy: 0.9952 - val_iou_score: 0.5476
# Epoch 49/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.9950 - iou_score: 0.5926
# Epoch 49: val_iou_score did not improve from 0.54761
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3553 - accuracy: 0.9950 - iou_score: 0.5926 - val_loss: 0.4144 - val_accuracy: 0.9914 - val_iou_score: 0.4374
# Epoch 50/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.9953 - iou_score: 0.6049
# Epoch 50: val_iou_score did not improve from 0.54761
# 36/36 [==============================] - 5s 138ms/step - loss: 0.3394 - accuracy: 0.9953 - iou_score: 0.6049 - val_loss: 0.3599 - val_accuracy: 0.9936 - val_iou_score: 0.5029
# 載入最佳模型: Unet_result/models/best_model_foldFold2.h5
# === 評估 Fold2 ===
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 測試結果 - Fold2:
#   平均 IoU: 0.5574
#   平均誤差(公分): 0.1684
#   誤差在0.5公分內準確率: 95.74%
#   誤差在1.0公分內準確率: 95.74%
#
# Processing Fold3...
# === 訓練 Fold3 ===
# 訓練資料: 找到 287 張圖像, 287 張遮罩
# 驗證資料: 找到 47 張圖像, 47 張遮罩
# 測試資料: 找到 47 張圖像, 47 張遮罩
# 未匹配的圖像檔案: ['../data/Fold3/train/img_1.2.826.0.1.3680043.8.498.10001065121843652267743449160233082683.jpg', '../data/Fold3/train/img_1.2.826.0.1.3680043.8.498.10001175380298620851477409998730672515.jpg', '../data/Fold3/train/img_1.2.826.0.1.3680043.8.498.10001274045312501651093242392099983211.jpg', '../data/Fold3/train/img_1.2.826.0.1.3680043.8.498.10002446304107330308555550280339793610.jpg', '../data/Fold3/train/img_1.2.826.0.1.3680043.8.498.10003638361010097105432298560780077394.jpg'] (總共 144 個)
# 匹配到 143 對圖像和遮罩 (原始圖像數: 287, 原始遮罩數: 287)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# 匹配到 47 對圖像和遮罩 (原始圖像數: 47, 原始遮罩數: 47)
# Epoch 1/50
# 36/36 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.6576 - iou_score: 0.0202
# Epoch 1: val_iou_score improved from -inf to 0.00305, saving model to Unet_result/models/best_model_foldFold3.h5
# /root/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...
# Epoch 16/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8448 - accuracy: 0.9503 - iou_score: 0.1400
# Epoch 16: val_iou_score did not improve from 0.17874
# 36/36 [==============================] - 5s 138ms/step - loss: 0.8448 - accuracy: 0.9503 - iou_score: 0.1400 - val_loss: 0.7131 - val_accuracy: 0.9647 - val_iou_score: 0.1755
# Epoch 17/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8356 - accuracy: 0.9549 - iou_score: 0.1519
# Epoch 17: val_iou_score did not improve from 0.17874
# 36/36 [==============================] - 5s 137ms/step - loss: 0.8356 - accuracy: 0.9549 - iou_score: 0.1519 - val_loss: 0.7249 - val_accuracy: 0.9620 - val_iou_score: 0.1653
# Epoch 18/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8262 - accuracy: 0.9581 - iou_score: 0.1603
# Epoch 18: val_iou_score did not improve from 0.17874
# 36/36 [==============================] - 5s 139ms/step - loss: 0.8262 - accuracy: 0.9581 - iou_score: 0.1603 - val_loss: 0.7239 - val_accuracy: 0.9622 - val_iou_score: 0.1675
# Epoch 19/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8186 - accuracy: 0.9594 - iou_score: 0.1646
# Epoch 19: val_iou_score improved from 0.17874 to 0.17922, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.8186 - accuracy: 0.9594 - iou_score: 0.1646 - val_loss: 0.7098 - val_accuracy: 0.9635 - val_iou_score: 0.1792
# Epoch 20/50
# 36/36 [==============================] - ETA: 0s - loss: 0.8085 - accuracy: 0.9628 - iou_score: 0.1800
# Epoch 20: val_iou_score did not improve from 0.17922
# 36/36 [==============================] - 5s 140ms/step - loss: 0.8085 - accuracy: 0.9628 - iou_score: 0.1800 - val_loss: 0.7209 - val_accuracy: 0.9620 - val_iou_score: 0.1691
# Epoch 21/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7980 - accuracy: 0.9658 - iou_score: 0.1905
# Epoch 21: val_iou_score improved from 0.17922 to 0.17931, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.7980 - accuracy: 0.9658 - iou_score: 0.1905 - val_loss: 0.7065 - val_accuracy: 0.9642 - val_iou_score: 0.1793
# Epoch 22/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7929 - accuracy: 0.9649 - iou_score: 0.1843
# Epoch 22: val_iou_score did not improve from 0.17931
# 36/36 [==============================] - 5s 138ms/step - loss: 0.7929 - accuracy: 0.9649 - iou_score: 0.1843 - val_loss: 0.7360 - val_accuracy: 0.9586 - val_iou_score: 0.1585
# Epoch 23/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7765 - accuracy: 0.9694 - iou_score: 0.2057
# Epoch 23: val_iou_score improved from 0.17931 to 0.22353, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.7765 - accuracy: 0.9694 - iou_score: 0.2057 - val_loss: 0.6439 - val_accuracy: 0.9741 - val_iou_score: 0.2235
# Epoch 24/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7630 - accuracy: 0.9733 - iou_score: 0.2300
# Epoch 24: val_iou_score improved from 0.22353 to 0.23779, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.7630 - accuracy: 0.9733 - iou_score: 0.2300 - val_loss: 0.6284 - val_accuracy: 0.9747 - val_iou_score: 0.2378
# Epoch 25/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7489 - accuracy: 0.9750 - iou_score: 0.2425
# Epoch 25: val_iou_score improved from 0.23779 to 0.27154, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.7489 - accuracy: 0.9750 - iou_score: 0.2425 - val_loss: 0.5932 - val_accuracy: 0.9783 - val_iou_score: 0.2715
# Epoch 26/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7391 - accuracy: 0.9751 - iou_score: 0.2421
# Epoch 26: val_iou_score did not improve from 0.27154
# 36/36 [==============================] - 5s 136ms/step - loss: 0.7391 - accuracy: 0.9751 - iou_score: 0.2421 - val_loss: 0.6882 - val_accuracy: 0.9667 - val_iou_score: 0.1919
# Epoch 27/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7248 - accuracy: 0.9767 - iou_score: 0.2528
# Epoch 27: val_iou_score did not improve from 0.27154
# 36/36 [==============================] - 5s 138ms/step - loss: 0.7248 - accuracy: 0.9767 - iou_score: 0.2528 - val_loss: 0.6157 - val_accuracy: 0.9762 - val_iou_score: 0.2417
# Epoch 28/50
# 36/36 [==============================] - ETA: 0s - loss: 0.7106 - accuracy: 0.9789 - iou_score: 0.2717
# Epoch 28: val_iou_score did not improve from 0.27154
# 36/36 [==============================] - 5s 141ms/step - loss: 0.7106 - accuracy: 0.9789 - iou_score: 0.2717 - val_loss: 0.6198 - val_accuracy: 0.9757 - val_iou_score: 0.2407
# Epoch 29/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.9818 - iou_score: 0.3005
# Epoch 29: val_iou_score improved from 0.27154 to 0.34475, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 169ms/step - loss: 0.6931 - accuracy: 0.9818 - iou_score: 0.3005 - val_loss: 0.4942 - val_accuracy: 0.9867 - val_iou_score: 0.3448
# Epoch 30/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.9823 - iou_score: 0.3069
# Epoch 30: val_iou_score did not improve from 0.34475
# 36/36 [==============================] - 5s 138ms/step - loss: 0.6775 - accuracy: 0.9823 - iou_score: 0.3069 - val_loss: 0.5820 - val_accuracy: 0.9792 - val_iou_score: 0.2681
# Epoch 31/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6664 - accuracy: 0.9833 - iou_score: 0.3137
# Epoch 31: val_iou_score did not improve from 0.34475
# 36/36 [==============================] - 5s 138ms/step - loss: 0.6664 - accuracy: 0.9833 - iou_score: 0.3137 - val_loss: 0.4986 - val_accuracy: 0.9855 - val_iou_score: 0.3417
# Epoch 32/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.9848 - iou_score: 0.3383
# Epoch 32: val_iou_score improved from 0.34475 to 0.37388, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 165ms/step - loss: 0.6484 - accuracy: 0.9848 - iou_score: 0.3383 - val_loss: 0.4685 - val_accuracy: 0.9891 - val_iou_score: 0.3739
# Epoch 33/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.9857 - iou_score: 0.3486
# Epoch 33: val_iou_score improved from 0.37388 to 0.42340, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.6281 - accuracy: 0.9857 - iou_score: 0.3486 - val_loss: 0.4098 - val_accuracy: 0.9905 - val_iou_score: 0.4234
# Epoch 34/50
# 36/36 [==============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.9870 - iou_score: 0.3715
# Epoch 34: val_iou_score improved from 0.42340 to 0.47293, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 165ms/step - loss: 0.6087 - accuracy: 0.9870 - iou_score: 0.3715 - val_loss: 0.3628 - val_accuracy: 0.9918 - val_iou_score: 0.4729
# Epoch 35/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5850 - accuracy: 0.9888 - iou_score: 0.4091
# Epoch 35: val_iou_score did not improve from 0.47293
# 36/36 [==============================] - 5s 140ms/step - loss: 0.5850 - accuracy: 0.9888 - iou_score: 0.4091 - val_loss: 0.4444 - val_accuracy: 0.9885 - val_iou_score: 0.3909
# Epoch 36/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.9893 - iou_score: 0.4137
# Epoch 36: val_iou_score improved from 0.47293 to 0.53200, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.5715 - accuracy: 0.9893 - iou_score: 0.4137 - val_loss: 0.3098 - val_accuracy: 0.9940 - val_iou_score: 0.5320
# Epoch 37/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5611 - accuracy: 0.9885 - iou_score: 0.3989
# Epoch 37: val_iou_score did not improve from 0.53200
# 36/36 [==============================] - 5s 135ms/step - loss: 0.5611 - accuracy: 0.9885 - iou_score: 0.3989 - val_loss: 0.4869 - val_accuracy: 0.9861 - val_iou_score: 0.3502
# Epoch 38/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5434 - accuracy: 0.9895 - iou_score: 0.4194
# Epoch 38: val_iou_score did not improve from 0.53200
# 36/36 [==============================] - 5s 138ms/step - loss: 0.5434 - accuracy: 0.9895 - iou_score: 0.4194 - val_loss: 0.3171 - val_accuracy: 0.9939 - val_iou_score: 0.5278
# Epoch 39/50
# 36/36 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.9920 - iou_score: 0.4817
# Epoch 39: val_iou_score did not improve from 0.53200
# 36/36 [==============================] - 5s 137ms/step - loss: 0.5137 - accuracy: 0.9920 - iou_score: 0.4817 - val_loss: 0.3184 - val_accuracy: 0.9935 - val_iou_score: 0.5313
# Epoch 40/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.9918 - iou_score: 0.4808
# Epoch 40: val_iou_score improved from 0.53200 to 0.56263, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 168ms/step - loss: 0.4953 - accuracy: 0.9918 - iou_score: 0.4808 - val_loss: 0.2902 - val_accuracy: 0.9951 - val_iou_score: 0.5626
# Epoch 41/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.9932 - iou_score: 0.5244
# Epoch 41: val_iou_score did not improve from 0.56263
# 36/36 [==============================] - 5s 138ms/step - loss: 0.4698 - accuracy: 0.9932 - iou_score: 0.5244 - val_loss: 0.3033 - val_accuracy: 0.9943 - val_iou_score: 0.5479
# Epoch 42/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.9936 - iou_score: 0.5394
# Epoch 42: val_iou_score did not improve from 0.56263
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4502 - accuracy: 0.9936 - iou_score: 0.5394 - val_loss: 0.3021 - val_accuracy: 0.9954 - val_iou_score: 0.5550
# Epoch 43/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4280 - accuracy: 0.9940 - iou_score: 0.5587
# Epoch 43: val_iou_score did not improve from 0.56263
# 36/36 [==============================] - 5s 138ms/step - loss: 0.4280 - accuracy: 0.9940 - iou_score: 0.5587 - val_loss: 0.3239 - val_accuracy: 0.9931 - val_iou_score: 0.5160
# Epoch 44/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4273 - accuracy: 0.9938 - iou_score: 0.5392
# Epoch 44: val_iou_score did not improve from 0.56263
# 36/36 [==============================] - 5s 139ms/step - loss: 0.4273 - accuracy: 0.9938 - iou_score: 0.5392 - val_loss: 0.3102 - val_accuracy: 0.9939 - val_iou_score: 0.5350
# Epoch 45/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.9934 - iou_score: 0.5274
# Epoch 45: val_iou_score improved from 0.56263 to 0.59589, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4166 - accuracy: 0.9934 - iou_score: 0.5274 - val_loss: 0.2643 - val_accuracy: 0.9956 - val_iou_score: 0.5959
# Epoch 46/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3840 - accuracy: 0.9950 - iou_score: 0.5925
# Epoch 46: val_iou_score did not improve from 0.59589
# 36/36 [==============================] - 5s 138ms/step - loss: 0.3840 - accuracy: 0.9950 - iou_score: 0.5925 - val_loss: 0.3239 - val_accuracy: 0.9939 - val_iou_score: 0.5177
# Epoch 47/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.9946 - iou_score: 0.5710
# Epoch 47: val_iou_score improved from 0.59589 to 0.60063, saving model to Unet_result/models/best_model_foldFold5.h5
# 36/36 [==============================] - 6s 170ms/step - loss: 0.3779 - accuracy: 0.9946 - iou_score: 0.5710 - val_loss: 0.2583 - val_accuracy: 0.9954 - val_iou_score: 0.6006
# Epoch 48/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.9939 - iou_score: 0.5554
# Epoch 48: val_iou_score did not improve from 0.60063
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3837 - accuracy: 0.9939 - iou_score: 0.5554 - val_loss: 0.2735 - val_accuracy: 0.9947 - val_iou_score: 0.5835
# Epoch 49/50
# 36/36 [==============================] - ETA: 0s - loss: 0.3843 - accuracy: 0.9942 - iou_score: 0.5608
# Epoch 49: val_iou_score did not improve from 0.60063
# 36/36 [==============================] - 5s 139ms/step - loss: 0.3843 - accuracy: 0.9942 - iou_score: 0.5608 - val_loss: 0.5264 - val_accuracy: 0.9887 - val_iou_score: 0.3189
# Epoch 50/50
# 36/36 [==============================] - ETA: 0s - loss: 0.4022 - accuracy: 0.9929 - iou_score: 0.5039
# Epoch 50: val_iou_score did not improve from 0.60063
# 36/36 [==============================] - 5s 138ms/step - loss: 0.4022 - accuracy: 0.9929 - iou_score: 0.5039 - val_loss: 0.2714 - val_accuracy: 0.9950 - val_iou_score: 0.5830
# 載入最佳模型: Unet_result/models/best_model_foldFold5.h5
# === 評估 Fold5 ===
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 測試結果 - Fold5:
#   平均 IoU: 0.5524
#   平均誤差(公分): 0.0946
#   誤差在0.5公分內準確率: 100.00%
#   誤差在1.0公分內準確率: 100.00%
#
# === 所有Fold平均績效 ===
# 平均 IoU: 0.5635
# 平均誤差(公分): 0.1200
# 誤差在0.5公分內準確率: 97.87%
# 誤差在1.0公分內準確率: 98.72%
#
# 所有結果已保存至: Unet_result/results/unet_results.csv
# Fold1 的訓練歷史曲線已保存至: Unet_result/figure/Fold1_training_history.png
# Fold2 的訓練歷史曲線已保存至: Unet_result/figure/Fold2_training_history.png
# Fold3 的訓練歷史曲線已保存至: Unet_result/figure/Fold3_training_history.png
# Fold4 的訓練歷史曲線已保存至: Unet_result/figure/Fold4_training_history.png
# Fold5 的訓練歷史曲線已保存至: Unet_result/figure/Fold5_training_history.png
